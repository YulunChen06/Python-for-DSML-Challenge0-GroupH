# %% [markdown]
# # Person D assignment: tags, genome, and advanced analysis
#
# This is an assignment notebook, not a completed analysis. Use the shared tables, write the tag/genome analysis yourself, and export the required handoff files.

# %%
from pathlib import Path
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))
from load_data import load_movielens
from preprocess import build_shared_tables, prepare_genome_scores, prepare_genome_tags

data_dir = Path(os.environ.get('MOVIELENS_DATA_DIR', PROJECT_ROOT / 'data' / 'ml-20m'))
frames = load_movielens(data_dir)
tables = build_shared_tables(frames['ratings'], frames['movies'], frames.get('tags'))
ratings = tables['ratings']
movies = tables['movies']
movie_stats = tables['movie_stats']
tags = tables['tags']
movie_tag_stats = tables['movie_tag_stats']
genome_scores_raw = frames.get('genome-scores', pd.DataFrame())
genome_tags_raw = frames.get('genome-tags', pd.DataFrame())
genome_scores = prepare_genome_scores(genome_scores_raw) if not genome_scores_raw.empty else pd.DataFrame()
genome_tags = prepare_genome_tags(genome_tags_raw) if not genome_tags_raw.empty else pd.DataFrame()
OUTPUT_DIR = PROJECT_ROOT / 'outputs' / 'summary_tables'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
FIGURE_DIR = PROJECT_ROOT / 'figures'
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Part A — clean tags and frequency
#
# TODO: document lowercase/strip normalization, inspect missing and duplicate applications, and report application frequency separately from movie and user coverage.

# %%
# TODO: implement tag cleaning, frequency, coverage, and tags-per-movie distributions.
# Required exports: tag_frequency.csv and movie_tag_stats.csv

# %% [markdown]
# ## Part B — tags versus movie popularity
#
# TODO: merge tag counts with `movie_stats`, report support-aware count metrics, and calculate a Spearman relationship. Do not infer causality from popularity.

# %%
# TODO: implement the tag-versus-popularity analysis and labeled figure.

# %% [markdown]
# ## Part C — genome coverage and selected movies
#
# TODO: check genome coverage and relevance ranges. Select representative movies with coverage and list their top genome tags.

# %%
# TODO: implement genome coverage checks, selected-movie profiles, and figures.
# Required export: selected_movie_genome_tags.csv

# %% [markdown]
# ## Part D — genre genome relevance profiles
#
# TODO: compare relevance profiles for at least three genres such as horror, romance, and action. Restrict to movies with genome coverage, report support, and create a heatmap or equivalent labeled comparison.

# %%
# TODO: implement genre-level genome profiles and a support-aware heatmap.
# Required export: genre_genome_profiles.csv

# %% [markdown]
# ## Part E — Challenge Question 3
#
# Compare user tags with genome tags using exact normalized matching first. Report match coverage and identify high-frequency/low-relevance and low-frequency/high-relevance cases. Keep any qualitative semantic comparison separate from exact matching.

# %%
# TODO: implement normalized matching, relevance aggregation, four-quadrant analysis, and plots.
# Required export: user_tag_genome_comparison.csv

# %% [markdown]
# ## Part F — stretch goal
#
# TODO: complete one documented stretch goal, preferably a leakage-safe rating baseline with a train/test split. If attempted, export baseline_predictor_rmse.csv and document cold-start handling. Add at least three findings, two limitations, normalization rules, match coverage, and methodology.

# %%
# TODO: implement the stretch goal only after the core tag/genome work is complete.
